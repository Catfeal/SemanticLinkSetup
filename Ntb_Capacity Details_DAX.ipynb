# %%
# %run Fnc_StartupFabricSempy
# Out:
# StatementMeta(, 54de9040-6ad5-42a0-95dc-79ba6402d21d, 8, Finished, Available, Finished)
# Warning: In reference Fnc_StartupFabricSempy run, the default lakehouse of the main notebook will be the effective default lakehouse of the session during reference run. Recommend using absolute path to read/write lakehouse in the referenced notebooks.

# %%
prm_starttime = datetime.now()
NotebookName = "Nbt_Capacty Details_DAX"

# %%
def fnc_Startup_DAX(_tableName):
    fnc_startUp(_tableName)
    LH_Name = "Lkh_CapacityReportData"
    lakehouse = mssparkutils.lakehouse.get(LH_Name)
    lh_abfs_path = lakehouse.get("properties").get("abfsPath")
    return lh_abfs_path
# Out:
# StatementMeta(, 54de9040-6ad5-42a0-95dc-79ba6402d21d, 11, Finished, Available, Finished)

# %% [markdown]
# ## Items ophalen en wegschrijven

# %%
Table_Name = 'landing_Items'
lh_abfs_path = fnc_Startup_DAX(Table_Name)
# Out:
# StatementMeta(, eb917ad7-62e0-4ff9-83dc-d9c9b3211f16, 37, Finished, Available, Finished)
# niet leeg
# SynapseWidget(Synapse.DataFrame, 8639756c-ca6f-4ef3-84ac-23be444b177f)

# %%
df = sempy_labs.evaluate_dax_impersonation(
dataset = 'DataVanFabriCapacityReport',
dax_query = """EVALUATE
SUMMARIZE(
			'Items',
			'Items'[Item],
			'Items'[ItemId],
			'Items'[ItemKind],
			'Items'[ItemName],
			'Items'[WorkspaceId],
			'Items'[capacityId],
			'Items'[Billable type]
        )
		""" )
df = fnc_PrepareColumns(df)
sparkdf = spark.createDataFrame(df)
sparkdf.write.format("delta").option("mergeSchema", "true").mode("append").save(f"{lh_abfs_path}/Tables/{Table_Name}")
# Out:
# StatementMeta(, eb917ad7-62e0-4ff9-83dc-d9c9b3211f16, 38, Finished, Available, Finished)

# %% [markdown]
# ## Capacities ophalen en wegschrijven

# %%
Table_Name = 'landing_Capacities'
lh_abfs_path = fnc_startUp(Table_Name)
LH_Name = "Lkh_CapacityReportData"
lakehouse = mssparkutils.lakehouse.get(LH_Name)
lh_abfs_path = lakehouse.get("properties").get("abfsPath")
# Out:
# StatementMeta(, eb917ad7-62e0-4ff9-83dc-d9c9b3211f16, 39, Finished, Available, Finished)
# niet leeg
# SynapseWidget(Synapse.DataFrame, 4dc47df6-4e43-48e7-81e9-d6644b94f032)

# %%
df = sempy_labs.evaluate_dax_impersonation(
dataset = 'DataVanFabriCapacityReport',
dax_query = """EVALUATE
SUMMARIZE(
			'Capacities',
			'Capacities'[capacityId],
			'Capacities'[Capacity Name],
			'Capacities'[capacityMemoryInGB],
			'Capacities'[capacityNumberOfVCores],
			'Capacities'[capacityPlan],
			'Capacities'[creationDate],
			'Capacities'[Owners],
			'Capacities'[region],
			'Capacities'[sku]
		)
		""" )
df = fnc_PrepareColumns(df)
sparkdf = spark.createDataFrame(df)
sparkdf.write.format("delta").option("mergeSchema", "true").mode("append").save(f"{lh_abfs_path}/Tables/{Table_Name}")
# Out:
# StatementMeta(, eb917ad7-62e0-4ff9-83dc-d9c9b3211f16, 40, Finished, Available, Finished)

# %% [markdown]
# ## Interactive details

# %%
Table_Name = 'landing_InteractiveDetails'
lh_abfs_path = fnc_startUp(Table_Name)
LH_Name = "Lkh_CapacityReportData"
lakehouse = mssparkutils.lakehouse.get(LH_Name)
lh_abfs_path = lakehouse.get("properties").get("abfsPath")
# Out:
# StatementMeta(, eb917ad7-62e0-4ff9-83dc-d9c9b3211f16, 41, Finished, Available, Finished)
# niet leeg
# SynapseWidget(Synapse.DataFrame, b894682f-b86c-48e9-be85-528fe9b6a446)

# %%
df = sempy_labs.evaluate_dax_impersonation(
dataset = 'DataVanFabriCapacityReport',
dax_query = """EVALUATE
		SUMMARIZE(
			'InteractiveDetail',
			'InteractiveDetail'[ItemId],
			'InteractiveDetail'[CUs],
			'InteractiveDetail'[Duration (s)],
			'InteractiveDetail'[OperationName],
			'InteractiveDetail'[OperationStartTime],
			'InteractiveDetail'[OperationEndTime],
			'InteractiveDetail'[Status],
			'InteractiveDetail'[Throttling (s)],
			'InteractiveDetail'[Key]
		)
		""" )
df = fnc_PrepareColumns(df)
sparkdf = spark.createDataFrame(df)
sparkdf.write.format("delta").option("mergeSchema", "true").mode("append").save(f"{lh_abfs_path}/Tables/{Table_Name}")
# Out:
# StatementMeta(, eb917ad7-62e0-4ff9-83dc-d9c9b3211f16, 42, Finished, Available, Finished)

# %% [markdown]
# ## Background details

# %%
Table_Name = 'landing_BackgroundDetails'
lh_abfs_path = fnc_startUp(Table_Name)
LH_Name = "Lkh_CapacityReportData"
lakehouse = mssparkutils.lakehouse.get(LH_Name)
lh_abfs_path = lakehouse.get("properties").get("abfsPath")
# Out:
# StatementMeta(, , -1, Cancelled, , Cancelled)

# %%
df = sempy_labs.evaluate_dax_impersonation(
dataset = 'DataVanFabriCapacityReport',
dax_query = """EVALUATE
		SUMMARIZE(
			'BackgroundDetail',
			'BackgroundDetail'[Key],
			'BackgroundDetail'[ItemId],
			'BackgroundDetail'[Duration (s)],
			'BackgroundDetail'[CUs],
			'BackgroundDetail'[OperationEndTime],
			'BackgroundDetail'[OperationName],
			'BackgroundDetail'[OperationStartTime],
			'BackgroundDetail'[Status],
			'BackgroundDetail'[Throttling (s)]
		)
		""" )
df = fnc_PrepareColumns(df)
sparkdf = spark.createDataFrame(df)
sparkdf.write.format("delta").option("mergeSchema", "true").mode("append").save(f"{lh_abfs_path}/Tables/{Table_Name}")
# Out:
# StatementMeta(, 54de9040-6ad5-42a0-95dc-79ba6402d21d, 9, Finished, Available, Finished)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 19
#      17 df = fnc_PrepareColumns(df)
#      18 sparkdf = spark.createDataFrame(df)
# ---> 19 sparkdf.write.format("delta").option("mergeSchema", "true").mode("append").save(f"{lh_abfs_path}/Tables/{Table_Name}")
#
# NameError: name 'lh_abfs_path' is not defined

# %% [markdown]
# ## storage by workspace and day

# %%
Table_Name = 'landing_StorageByWorkspaceAndDay'
lh_abfs_path = fnc_Startup_DAX(Table_Name)
# Out:
# StatementMeta(, 54de9040-6ad5-42a0-95dc-79ba6402d21d, 12, Finished, Available, Finished)
# niet leeg
# SynapseWidget(Synapse.DataFrame, ec6b52f5-7dc9-457f-9df3-da3dd6fec744)

# %%
df = sempy_labs.evaluate_dax_impersonation(
dataset = 'DataVanFabriCapacityReport',
dax_query = """EVALUATE
        SUMMARIZE(
			'StorageByWorkspacesandDay',
			'StorageByWorkspacesandDay'[WorkspaceId],
			'StorageByWorkspacesandDay'[OperationName],
			'StorageByWorkspacesandDay'[Hours],
			'StorageByWorkspacesandDay'[StaticStorageInGb],
			'StorageByWorkspacesandDay'[Utilization (GB)],
			'StorageByWorkspacesandDay'[Date],
			'StorageByWorkspacesandDay'[WorkspaceKey],
			'StorageByWorkspacesandDay'[WorkloadKind],
			'StorageByWorkspacesandDay'[PremiumCapacityId],
			'StorageByWorkspacesandDay'[Billing type]
		)   
		""" )
df = fnc_PrepareColumns(df)
sparkdf = spark.createDataFrame(df)
sparkdf.write.format("delta").option("mergeSchema", "true").mode("append").save(f"{lh_abfs_path}/Tables/{Table_Name}")
# Out:
# StatementMeta(, 54de9040-6ad5-42a0-95dc-79ba6402d21d, 13, Finished, Available, Finished)

# %% [markdown]
# ## workspaces

# %%
Table_Name = 'landing_Workspaces'
lh_abfs_path = fnc_Startup_DAX(Table_Name)
# Out:
# StatementMeta(, 54de9040-6ad5-42a0-95dc-79ba6402d21d, 14, Finished, Available, Finished)
# niet leeg
# SynapseWidget(Synapse.DataFrame, 05389709-cd1e-4c9d-a914-2554b7963d6d)

# %%
df = sempy_labs.evaluate_dax_impersonation(
dataset = 'DataVanFabriCapacityReport',
dax_query = """EVALUATE
		SUMMARIZE(
			'Workspaces',
			'Workspaces'[PremiumCapacityId],
			'Workspaces'[WorkspaceId],
			'Workspaces'[WorkspaceKey],
			'Workspaces'[WorkspaceName],
			'Workspaces'[WorkspaceProvisionState]
		)   
		""" )
df = fnc_PrepareColumns(df)
sparkdf = spark.createDataFrame(df)
sparkdf.write.format("delta").option("mergeSchema", "true").mode("append").save(f"{lh_abfs_path}/Tables/{Table_Name}")
# Out:
# StatementMeta(, 54de9040-6ad5-42a0-95dc-79ba6402d21d, 15, Finished, Available, Finished)

# %% [markdown]
# ## afronden

# %%
prm_endtime = datetime.utcnow()
fnc_LognotebookRefresh(NotebookName, prm_starttime, prm_endtime)
