# %% [markdown]
# De benamingen voor de tabellen die we gaan vullen

# %%
# %run Fnc_StartupFabricSempy
# Out:
# StatementMeta(, a7d46e7d-0a33-4161-b28b-2fee8097d834, 9, Finished, Available, Finished)

# %%
prm_starttime = datetime.now()
NotebookName = "Nbt_Landing_GetCapacities"
# Out:
# StatementMeta(, a7d46e7d-0a33-4161-b28b-2fee8097d834, 10, Finished, Available, Finished)

# %%
Table_Name = 'Landing_Fabric_Capacities'
# Out:
# StatementMeta(, a7d46e7d-0a33-4161-b28b-2fee8097d834, 11, Finished, Available, Finished)

# %%
lh_abfs_path = fnc_startUp(Table_Name)
# Out:
# StatementMeta(, a7d46e7d-0a33-4161-b28b-2fee8097d834, 12, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 0d80ad0d-8087-4530-8596-889f701d93e3)

# %% [markdown]
# Alle benodigde lijsten om de code vlot te laten lopen

# %%
#fill list of workspaces
workspaces = fabric.list_capacities()
workspaces = fnc_PrepareColumns(workspaces)
sparkdf = spark.createDataFrame(workspaces)
sparkdf.write.format("delta").option("mergeSchema", "true").mode("overwrite").save(f"{lh_abfs_path}/Tables/{Table_Name}")
# Out:
# StatementMeta(, a7d46e7d-0a33-4161-b28b-2fee8097d834, 13, Finished, Available, Finished)

# %%
prm_endtime = datetime.utcnow()
fnc_LognotebookRefresh(NotebookName, prm_starttime, prm_endtime)
# Out:
# StatementMeta(, a7d46e7d-0a33-4161-b28b-2fee8097d834, 16, Finished, Available, Finished)
